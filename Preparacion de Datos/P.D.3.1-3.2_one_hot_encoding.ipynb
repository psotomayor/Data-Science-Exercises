# %% [markdown]
# <img src="https://s3.amazonaws.com/datascienceheroes.com/EDV/360_banner_python.png" width="400px">
#
#
# # Escuela de Datos Vivos
#
# ## LAB P.D.3.1-3.2: Introducción al one hot encoding / dummy vars
# Creado por Pablo Casas | https://escueladedatosvivos.ai

# %% [markdown]
# Resuelto por Pablo Sotomayor

# %%
# Librerías que utilizaremos

import pickle
import numpy as np
import pandas as pd
import seaborn as sns
from funpymodeling.exploratory import status 
from pandas_profiling import ProfileReport
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# 1) Cargar los datos de 'data/hotels_smp.csv' (fuente: [tidytuesday](https://github.com/rfordatascience/tidytuesday/blob/master/data/2020/2020-02-11/readme.md))
#
# 2) Separar en training (TR) y testing (TS).
#
# 3) Discretizar las variables categóricas usando TR (`get_dummies`), y aplicar la discretización en TS. Dentro del TS, modifiquen "a mano" una de las variables categóricas para que haya un valor nuevo.
#
# 4) Parte fundamental del data scientist es inspeccionar que las transformaciones, y los flujos de datos sean los esperados. Por tal motivo debe auditarse el resultado: Revisar que la transformación sea la correcta.

# %% [markdown]
# ## Solución

# %% [markdown]
# #### 1) Carga de datos

# %%
data = pd.read_csv('../data/hotels_smp.csv', sep=',')

print(f"Cantidad de registros: {data.shape[0]}")
print(f"Cantidad de variables: {data.shape[1]}")
# Out:
# Cantidad de registros: 3000
# Cantidad de variables: 32

# %% [markdown]
# Inspeccionamos los datos tomando una muestra aleatoria de ellos.

# %%
data.sample(5)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2464  Resort Hotel            0        176               2016
# 275     City Hotel            1        152               2016
# 1519    City Hotel            1         35               2017
# 2331  Resort Hotel            0        234               2016
# 1680    City Hotel            0        118               2016
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2464               July                        30                         19
# 275                June                        26                         19
# 1519             August                        32                          8
# 2331          September                        37                          9
# 1680               June                        24                          6
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 2464                        1                     5       2  ...
# 275                         2                     3       2  ...
# 1519                        0                     1       2  ...
# 2331                        1                     2       2  ...
# 1680                        1                     2       1  ...
#
#       deposit_type  agent company days_in_waiting_list    customer_type  \
# 2464    No Deposit  240.0     NaN                    0        Transient
# 275     No Deposit    8.0     NaN                    0        Transient
# 1519    No Deposit  229.0     NaN                    0  Transient-Party
# 2331    No Deposit    NaN     NaN                    0  Transient-Party
# 1680    No Deposit  191.0     NaN                    0  Transient-Party
#
#          adr  required_car_parking_spaces  total_of_special_requests  \
# 2464  193.67                            1                          2
# 275   108.12                            0                          0
# 1519   90.00                            0                          0
# 2331   77.03                            0                          1
# 1680  110.00                            0                          0
#
#       reservation_status reservation_status_date
# 2464           Check-Out              2016-07-25
# 275             Canceled              2016-03-21
# 1519            Canceled              2017-07-07
# 2331           Check-Out              2016-09-12
# 1680           Check-Out              2016-06-09
#
# [5 rows x 32 columns]

# %% [markdown]
# Revisamos el estado de los datos

# %%
status(data)
# Out:
#                           variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                            hotel      0  0.000000        0  0.000000
# 1                      is_canceled      0  0.000000     1901  0.633667
# 2                        lead_time      0  0.000000      147  0.049000
# 3                arrival_date_year      0  0.000000        0  0.000000
# 4               arrival_date_month      0  0.000000        0  0.000000
# 5         arrival_date_week_number      0  0.000000        0  0.000000
# 6        arrival_date_day_of_month      0  0.000000        0  0.000000
# 7          stays_in_weekend_nights      0  0.000000     1327  0.442333
# 8             stays_in_week_nights      0  0.000000      152  0.050667
# 9                           adults      0  0.000000       13  0.004333
# 10                        children      0  0.000000     2793  0.931000
# 11                          babies      0  0.000000     2973  0.991000
# 12                            meal      0  0.000000        0  0.000000
# 13                         country     22  0.007333        0  0.000000
# 14                  market_segment      0  0.000000        0  0.000000
# 15            distribution_channel      0  0.000000        0  0.000000
# 16               is_repeated_guest      0  0.000000     2907  0.969000
# 17          previous_cancellations      0  0.000000     2833  0.944333
# 18  previous_bookings_not_canceled      0  0.000000     2907  0.969000
# 19              reserved_room_type      0  0.000000        0  0.000000
# 20              assigned_room_type      0  0.000000        0  0.000000
# 21                 booking_changes      0  0.000000     2553  0.851000
# 22                    deposit_type      0  0.000000        0  0.000000
# 23                           agent    398  0.132667        0  0.000000
# 24                         company   2823  0.941000        0  0.000000
# 25            days_in_waiting_list      0  0.000000     2911  0.970333
# 26                   customer_type      0  0.000000        0  0.000000
# 27                             adr      0  0.000000       47  0.015667
# 28     required_car_parking_spaces      0  0.000000     2817  0.939000
# 29       total_of_special_requests      0  0.000000     1754  0.584667
# 30              reservation_status      0  0.000000        0  0.000000
# 31         reservation_status_date      0  0.000000        0  0.000000
#
#     unique     type
# 0        2   object
# 1        2    int64
# 2      392    int64
# 3        3    int64
# 4       12   object
# 5       53    int64
# 6       31    int64
# 7        9    int64
# 8       19    int64
# 9        4    int64
# 10       4    int64
# 11       2    int64
# 12       5   object
# 13      74   object
# 14       7   object
# 15       4   object
# 16       2    int64
# 17      10    int64
# 18      16    int64
# 19       8   object
# 20      10   object
# 21       9    int64
# 22       3   object
# 23     166  float64
# 24      79  float64
# 25      51    int64
# 26       4   object
# 27     980  float64
# 28       3    int64
# 29       5    int64
# 30       3   object
# 31     777   object

# %% [markdown]
# Vimos en un proyecto que anterior que la variable 'reservation_status' no da información, pues coincide con los registros de la variable a predecir. La variable "reservation_status_date" tampoco da información relevante, también la eliminamos. Hay variables categóricas mal declaradas como numéricas: "is_canceled", "is_repeated_guest", y "babies". Hacemos las transformaciones a los datos.

# %%
data_original = data.copy()

data = data.drop(['reservation_status', 'reservation_status_date'], axis=1)

data['is_canceled'] = data['is_canceled'].astype('str')
data['is_canceled'] = data['is_canceled'].replace('0', 'no').replace('1', 'yes') 

data['is_repeated_guest'] = data['is_repeated_guest'].astype('str')
data['is_repeated_guest'] = data['is_repeated_guest'].replace('0', 'no').replace('1', 'yes')    

data['babies'] = data['babies'].astype('str')
data['babies'] = data['babies'].replace('0', 'no').replace('1', 'yes')

# %% [markdown]
# #### 2) Determinación de los conjuntos de entrenamiento (TR) y de testeo (TS)

# %% [markdown]
# Establecemos las variables independientes y la variable a predecir

# %%
x_data, y_data = data.drop('is_canceled', axis=1), data['is_canceled']

# %% [markdown]
# Dividimos los datos en TR y TS. Elegimos un tamaño de 20% para los datos de testeo y adoptamos una semilla para reproducir los resultados.

# %%
x_tr, x_ts, y_tr, y_ts = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

# %% [markdown]
# Juntamos los datos que corresponden a TR y TS

# %%
TR, TS = pd.concat([x_tr, y_tr], axis=1), pd.concat([x_ts, y_ts], axis=1)

# %% [markdown]
# Vimos que la variable "deposit_type" tiene las clases muy desbalanceadas. Revisamos que valores se encuentran en TR y TS

# %%
TR['deposit_type'].value_counts()
# Out:
# No Deposit    2104
# Non Refund     294
# Refundable       2
# Name: deposit_type, dtype: int64

# %%
TS['deposit_type'].value_counts()
# Out:
# No Deposit    528
# Non Refund     72
# Name: deposit_type, dtype: int64

# %% [markdown]
# Por lo tanto, en TR hay valores que TS "no ha visto", lo cual es ideal para nuestro problema.

# %% [markdown]
# #### 3) Discretizamos las variables categóricas en TR

# %% [markdown]
# Pasamos primero todas las variables a numéricas con el método one-hot encoding. Agregamos una categoría para los valores nulos y eliminamos la redundancia en las entradas.

# %%
TR_ohe = pd.get_dummies(TR, drop_first=True, dummy_na=True)

# %% [markdown]
# Este método genera nuevos datos innecesarios para el caso de registros que no tenían variables nulas. Eliminamos esos nuevos atributos.

# %%
vars_to_drop = status(TR_ohe).query("unique==1")['variable']

TR_ohe = TR_ohe.drop(vars_to_drop, axis=1)

# %% [markdown]
# Inspecciamos los datos en TR

# %%
TR_ohe.head(5)
# Out:
#       lead_time  arrival_date_year  arrival_date_week_number  \
# 2370         30               2016                        22
# 1774          9               2016                        18
# 731         135               2016                        40
# 271          26               2016                        47
# 1077          0               2016                        31
#
#       arrival_date_day_of_month  stays_in_weekend_nights  \
# 2370                         23                        1
# 1774                         29                        0
# 731                          25                        2
# 271                          17                        0
# 1077                         29                        0
#
#       stays_in_week_nights  adults  children  previous_cancellations  \
# 2370                     1       2         0                       0
# 1774                     2       1         0                       0
# 731                      0       3         0                       0
# 271                      2       2         0                       0
# 1077                     1       2         0                       0
#
#       previous_bookings_not_canceled  ...  assigned_room_type_G  \
# 2370                               0  ...                     0
# 1774                               0  ...                     0
# 731                                0  ...                     0
# 271                                0  ...                     0
# 1077                               0  ...                     0
#
#       assigned_room_type_H  assigned_room_type_I  assigned_room_type_K  \
# 2370                     0                     0                     0
# 1774                     0                     0                     0
# 731                      0                     0                     0
# 271                      0                     0                     0
# 1077                     0                     0                     0
#
#       deposit_type_Non Refund  deposit_type_Refundable  customer_type_Group  \
# 2370                        0                        0                    0
# 1774                        0                        0                    0
# 731                         0                        0                    0
# 271                         0                        0                    0
# 1077                        0                        0                    0
#
#       customer_type_Transient  customer_type_Transient-Party  is_canceled_yes
# 2370                        1                              0                1
# 1774                        0                              1                0
# 731                         1                              0                0
# 271                         1                              0                0
# 1077                        1                              0                0
#
# [5 rows x 137 columns]

# %% [markdown]
# Revisamos las etiquetas de los atributos

# %%
TR_ohe.columns.to_list()
# Out:
# ['lead_time',
#  'arrival_date_year',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'booking_changes',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'hotel_Resort Hotel',
#  'arrival_date_month_August',
#  'arrival_date_month_December',
#  'arrival_date_month_February',
#  'arrival_date_month_January',
#  'arrival_date_month_July',
#  'arrival_date_month_June',
#  'arrival_date_month_March',
#  'arrival_date_month_May',
#  'arrival_date_month_November',
#  'arrival_date_month_October',
#  'arrival_date_month_September',
#  'babies_yes',
#  'meal_FB',
#  'meal_HB',
#  'meal_SC',
#  'meal_Undefined',
#  'country_ARE',
#  'country_ARG',
#  'country_ARM',
#  'country_AUS',
#  'country_AUT',
#  'country_BDI',
#  'country_BEL',
#  'country_BGR',
#  'country_BRA',
#  'country_CHE',
#  'country_CHL',
#  'country_CHN',
#  'country_CN',
#  'country_COL',
#  'country_CRI',
#  'country_CYP',
#  'country_CZE',
#  'country_DEU',
#  'country_DNK',
#  'country_DZA',
#  'country_EGY',
#  'country_ESP',
#  'country_EST',
#  'country_FIN',
#  'country_FRA',
#  'country_GBR',
#  'country_GRC',
#  'country_HKG',
#  'country_HRV',
#  'country_HUN',
#  'country_IDN',
#  'country_IND',
#  'country_IRL',
#  'country_IRN',
#  'country_ISL',
#  'country_ISR',
#  'country_ITA',
#  'country_JPN',
#  'country_KIR',
#  'country_KOR',
#  'country_LBN',
#  'country_LTU',
#  'country_LUX',
#  'country_MAR',
#  'country_MEX',
#  'country_MOZ',
#  'country_MYS',
#  'country_NGA',
#  'country_NLD',
#  'country_NOR',
#  'country_NZL',
#  'country_OMN',
#  'country_PHL',
#  'country_POL',
#  'country_PRT',
#  'country_QAT',
#  'country_ROU',
#  'country_RUS',
#  'country_SGP',
#  'country_SRB',
#  'country_SVK',
#  'country_SVN',
#  'country_SWE',
#  'country_THA',
#  'country_TUN',
#  'country_TUR',
#  'country_UKR',
#  'country_URY',
#  'country_USA',
#  'country_ZAF',
#  'country_nan',
#  'market_segment_Complementary',
#  'market_segment_Corporate',
#  'market_segment_Direct',
#  'market_segment_Groups',
#  'market_segment_Offline TA/TO',
#  'market_segment_Online TA',
#  'distribution_channel_Direct',
#  'distribution_channel_GDS',
#  'distribution_channel_TA/TO',
#  'is_repeated_guest_yes',
#  'reserved_room_type_B',
#  'reserved_room_type_C',
#  'reserved_room_type_D',
#  'reserved_room_type_E',
#  'reserved_room_type_F',
#  'reserved_room_type_G',
#  'reserved_room_type_H',
#  'assigned_room_type_B',
#  'assigned_room_type_C',
#  'assigned_room_type_D',
#  'assigned_room_type_E',
#  'assigned_room_type_F',
#  'assigned_room_type_G',
#  'assigned_room_type_H',
#  'assigned_room_type_I',
#  'assigned_room_type_K',
#  'deposit_type_Non Refund',
#  'deposit_type_Refundable',
#  'customer_type_Group',
#  'customer_type_Transient',
#  'customer_type_Transient-Party',
#  'is_canceled_yes']

# %% [markdown]
# Si deseamos guardar el encoding para usarlo posteriormente en producción utilizamos la librería pickle

# %%
with open('categories_TR_ohe.pickle', 'wb') as handle:
    pickle.dump(TR_ohe.columns, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Para cargar el encoding usamos la misma librería

# %%
with open('categories_TR_ohe.pickle', 'rb') as handle:
    TR_ohe_col = pickle.load(handle)

# %% [markdown]
# Elegimos una de las variables categóricas en el TS para que haya un valor nuevo (es decir, que no fue entrenado en el modelo).
#
# Variable elegida: deposit_type, agregamos el dato "Partial Refund". Cambiamos el 1% de los datos a ese valor. Los índices de los datos que transformaremos son elegidos al azar con una semilla para reproducir los resultados

# %%
np.random.seed(40)

indexs = np.random.choice(TS.index.to_list(), size=int(0.1*TS.shape[0]), replace=False)
TS['deposit_type'].update(pd.Series(len(indexs)*['Partial Refund'], index=indexs))
TS['deposit_type'].value_counts()
# Out:
# No Deposit        474
# Non Refund         66
# Partial Refund     60
# Name: deposit_type, dtype: int64

# %% [markdown]
# Hacemos get_dummies al TS, con las mismas condiciones que se lo hicimos al TR.

# %%
TS_ohe = pd.get_dummies(TS, drop_first=True, dummy_na=True)

# %%
vars_to_drop = status(TS_ohe).query("unique==1")['variable']

TS_ohe = TS_ohe.drop(vars_to_drop, axis=1)

# %%
TS_ohe.head(5)
# Out:
#       lead_time  arrival_date_year  arrival_date_week_number  \
# 311         230               2016                        37
# 1025        182               2017                        17
# 1587        243               2015                        39
# 2941        260               2016                        39
# 2980        165               2016                        29
#
#       arrival_date_day_of_month  stays_in_weekend_nights  \
# 311                           6                        0
# 1025                         23                        2
# 1587                         20                        2
# 2941                         22                        0
# 2980                         11                        3
#
#       stays_in_week_nights  adults  children  previous_cancellations  \
# 311                      5       2         0                       0
# 1025                     2       2         0                       0
# 1587                     2       2         0                       0
# 2941                     3       2         0                       0
# 2980                     7       2         0                       0
#
#       previous_bookings_not_canceled  ...  assigned_room_type_G  \
# 311                                0  ...                     0
# 1025                               0  ...                     0
# 1587                               0  ...                     0
# 2941                               0  ...                     0
# 2980                               0  ...                     0
#
#       assigned_room_type_H  assigned_room_type_I  assigned_room_type_K  \
# 311                      0                     0                     0
# 1025                     0                     0                     0
# 1587                     0                     0                     0
# 2941                     0                     0                     0
# 2980                     0                     0                     0
#
#       deposit_type_Non Refund  deposit_type_Partial Refund  \
# 311                         0                            1
# 1025                        0                            0
# 1587                        0                            0
# 2941                        0                            0
# 2980                        0                            0
#
#       customer_type_Group  customer_type_Transient  \
# 311                     0                        0
# 1025                    0                        1
# 1587                    0                        0
# 2941                    0                        0
# 2980                    0                        1
#
#       customer_type_Transient-Party  is_canceled_yes
# 311                               1                1
# 1025                              0                1
# 1587                              1                0
# 2941                              1                1
# 2980                              0                1
#
# [5 rows x 107 columns]

# %% [markdown]
# Pero queremos entrenar a nuestro modelo con las mismas variables que el TR, para esto usamos la función reindex

# %%
TS_ohe_TRcols = pd.get_dummies(TS_ohe).reindex(columns=TR_ohe_col)

# %%
TS_ohe_TRcols.head(5)
# Out:
#       lead_time  arrival_date_year  arrival_date_week_number  \
# 311         230               2016                        37
# 1025        182               2017                        17
# 1587        243               2015                        39
# 2941        260               2016                        39
# 2980        165               2016                        29
#
#       arrival_date_day_of_month  stays_in_weekend_nights  \
# 311                           6                        0
# 1025                         23                        2
# 1587                         20                        2
# 2941                         22                        0
# 2980                         11                        3
#
#       stays_in_week_nights  adults  children  previous_cancellations  \
# 311                      5       2         0                       0
# 1025                     2       2         0                       0
# 1587                     2       2         0                       0
# 2941                     3       2         0                       0
# 2980                     7       2         0                       0
#
#       previous_bookings_not_canceled  ...  assigned_room_type_G  \
# 311                                0  ...                     0
# 1025                               0  ...                     0
# 1587                               0  ...                     0
# 2941                               0  ...                     0
# 2980                               0  ...                     0
#
#       assigned_room_type_H  assigned_room_type_I  assigned_room_type_K  \
# 311                      0                     0                     0
# 1025                     0                     0                     0
# 1587                     0                     0                     0
# 2941                     0                     0                     0
# 2980                     0                     0                     0
#
#       deposit_type_Non Refund  deposit_type_Refundable  customer_type_Group  \
# 311                         0                      NaN                    0
# 1025                        0                      NaN                    0
# 1587                        0                      NaN                    0
# 2941                        0                      NaN                    0
# 2980                        0                      NaN                    0
#
#       customer_type_Transient  customer_type_Transient-Party  is_canceled_yes
# 311                         0                              1                1
# 1025                        1                              0                1
# 1587                        0                              1                0
# 2941                        0                              1                1
# 2980                        1                              0                1
#
# [5 rows x 137 columns]

# %%
TS_ohe_TRcols["deposit_type_Refundable"].value_counts()
# Out:
# Series([], Name: deposit_type_Refundable, dtype: int64)

# %% [markdown]
# El atributo "deposit_type_Refundable" es una categoría faltante previo a haber hecho el one-hot encoding al TS. Lo reemplazamos por ceros.

# %%
TS_ohe_TRcols = pd.get_dummies(TS_ohe).reindex(columns=TR_ohe_col, fill_value=0)

# %%
TS_ohe_TRcols.head(5)
# Out:
#       lead_time  arrival_date_year  arrival_date_week_number  \
# 311         230               2016                        37
# 1025        182               2017                        17
# 1587        243               2015                        39
# 2941        260               2016                        39
# 2980        165               2016                        29
#
#       arrival_date_day_of_month  stays_in_weekend_nights  \
# 311                           6                        0
# 1025                         23                        2
# 1587                         20                        2
# 2941                         22                        0
# 2980                         11                        3
#
#       stays_in_week_nights  adults  children  previous_cancellations  \
# 311                      5       2         0                       0
# 1025                     2       2         0                       0
# 1587                     2       2         0                       0
# 2941                     3       2         0                       0
# 2980                     7       2         0                       0
#
#       previous_bookings_not_canceled  ...  assigned_room_type_G  \
# 311                                0  ...                     0
# 1025                               0  ...                     0
# 1587                               0  ...                     0
# 2941                               0  ...                     0
# 2980                               0  ...                     0
#
#       assigned_room_type_H  assigned_room_type_I  assigned_room_type_K  \
# 311                      0                     0                     0
# 1025                     0                     0                     0
# 1587                     0                     0                     0
# 2941                     0                     0                     0
# 2980                     0                     0                     0
#
#       deposit_type_Non Refund  deposit_type_Refundable  customer_type_Group  \
# 311                         0                        0                    0
# 1025                        0                        0                    0
# 1587                        0                        0                    0
# 2941                        0                        0                    0
# 2980                        0                        0                    0
#
#       customer_type_Transient  customer_type_Transient-Party  is_canceled_yes
# 311                         0                              1                1
# 1025                        1                              0                1
# 1587                        0                              1                0
# 2941                        0                              1                1
# 2980                        1                              0                1
#
# [5 rows x 137 columns]

# %%
TS_ohe_TRcols['deposit_type_Refundable'].value_counts()
# Out:
# 0    600
# Name: deposit_type_Refundable, dtype: int64

# %% [markdown]
# Vemos que se ha solucionado el problema.

# %%
TS_ohe_TRcols['deposit_type_Non Refund'].value_counts()
# Out:
# 0    534
# 1     66
# Name: deposit_type_Non Refund, dtype: int64
